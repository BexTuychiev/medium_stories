# %% [markdown]
# # Top X Resources For Aspiring Data Scientists
# ## Learn from the same resources that put people in FAANG companies
# <img src='images/pexels.jpg'></img>
# <figcaption style="text-align: center;">
#     <strong>
#         Photo by
#         <a href='https://www.pexels.com/@ninauhlikova?utm_content=attributionCopyText&utm_medium=referral&utm_source=pexels'>Nina Uhlíková</a>
#         on
#         <a href='https://www.pexels.com/photo/person-standing-on-hand-rails-with-arms-wide-open-facing-the-mountains-and-clouds-725255/?utm_content=attributionCopyText&utm_medium=referral&utm_source=pexels'>Pexels</a>
#     </strong>
# </figcaption>

# %% [markdown]
# ### Data Science Can Be Overwhelming

# %% [markdown]
# ### 1. DataCamp.com

# %% [markdown]
# ![image.png](attachment:d67cb1d5-cbd1-491c-bb83-a4e86dc5838a.png)
#
# Without a question, my number one recommendation to get started in data science would be DataCamp. There are many reasons for this platform to be my first choice.
#
# First of all, when I was a complete beginner I struggled a lot with finding out what to learn and more importantly, in what order. I would switch from one source to another after finding out that I did not have the necessary background knowledge to learn from there. It was a vicious circle and it was making my learning process much less enjoyable.
#
# After discovering DataCamp, I realized I struck gold. DataCamp's specialized career tracks were what I needed. DataCamp's entire course library, consisting of more than 300 courses were categorized and put in order for some of the most demanding professions in the job market:
#
# ![image.png](attachment:59b4900f-68c5-4fe9-a027-5043399d1845.png)
#
# After subscribing to the platform, I immediately started Data Scientist career track and by the time I finished I learned more than I could have hoped to learn in such a short amount of time.
#
# Apart from Career Tracks, there are also small skill tracks consisting of 3 or 4 courses aimed at a single specific skill such as data visualization, data cleaning, statistics fundamentals and many more:
#
# ![image.png](attachment:dc10e819-aaec-46d1-93f8-70960a548160.png)

# %% [markdown]
# As you can see from the above screenshots, there are many more features of the platform. Specifically, there are daily practice problems as well as general assessments which really challenge you on certain skills you acquired.

# %% [markdown]
# In terms of price, their basic plan that gives access to all courses and career tracks for 150$, billed anually. Their premium plan, which is much more expensive gives access to all projects too but I would advise getting the basic plan because you can always come up with your own practice projects.

# %% [markdown]
# ### 2. Udacity

# %% [markdown]
# ![image.png](attachment:db2cc577-05c4-45ff-b0f7-bc29c7c40d11.png)

# %% [markdown]
# My next favorite platform to learn data science is Udacity. Apart from their super generous free courses, Udacity offers full-fledged programs called Nanodegrees which are similar to DataCamp career tracks.
#
# The difference is that they put much more emphasis on hands-on practice. Each Nanodegree contains chapters filled with video lessons. These lessons are conducted by top experts who work in Silicon Valley and give lectures in top universities like Harvard and Stanford. Each chapter contains several challenging practice problems which really put things in perspective of whether you actually learned the concept or not.
#
# ![image.png](attachment:9f54c647-dc24-42c7-93bb-61ab3210d70d.png)
#
# But most importantly, each Nanodegree contains at least 4 or 5 capstone real-world projects. Mind you, these are not your typical "real-world" projects you see out on other platforms where they basically guide you through the process holding your hands. These projects are real, hard challenges that tests all the skills you learned in a chapter. You will just be given the data and instructions and that's it.
#
# The project submissions will be checked and given thorough feedback by experts on the platform according to project criteria. Udacity also has a vibrant community of its all alumni and students where they can share projects and ask questions.
#
# ![image.png](attachment:15d882bb-ebe6-47e4-a65b-79c1e69c541f.png)
#
# As a final advantage, not seen in many other platforms, is their one-on-one career support. If you subscribe to one of their Nanodegrees, you immediately get access to monthly Resume, LinkedIn, and GitHub profile reviews. Also, each month you get 30 minutes of one-on-one call with an industry expert which is simply, awesome. They also provide with training on interviews, CV building and many other soft skills you direly need in today's job market.
#
# Sounds too good to be true? Well, there is a big catch! It is very expensive. Their monthly subscription, which is the only one, costs 400$ a month. If you don't happen to catch one of their frequent discounts which go up to 75%, you are going to have to spend a fortune to get access to this world-class platform.

# %% [markdown]
# ### 3. Coursera

# %% [markdown]
# ![image.png](attachment:49085087-a80b-461b-bfad-d2934a747cf4.png)
#
# The final paid platform in this list is Coursera. Its main draw is its world-class quality courses and specializations offered by the biggest names in industry.
#
# It boasts itself by being the host to courses and programs offered by massive companies like Google, IBM, Facebook and also top universities such as Harvard, Oxford, Stanford, John Hopkins and many others.
#
# You can take all courses completely free which gives access to view and study the material and videos in the course. If you want access to coding exercises which are really fun and challenging and earn a certificate by recognized industry leaders, you have to pay monthly subscription.
#
# Some of the certificates on the platform like IBM Professional Data Science Certification is recognized all around the globe and provides credibility for your CV.

# %% [markdown]
# ### 4. YouTube and Other Blogs

# %% [markdown]
# Believe it or not, the above 3 resources were mostly all I needed and still need to continue my Data Science journey. However, along your path, you will inevitably face some topics you may find impossible to understand.
#
# Whenever I found the videos or the lessons in the above sources difficult to understand, I would usually seek additional sources and end up finding the answers I needed at YouTube or just in some blogs  in the far corners of the Internet.
#
# Over time, I realized that I was visiting some of the destinations more frequently than others. Specifically, I spent a lot of my time learning math on YouTube. Especially, 3Blue1Brown channel is a gift to the world when it comes to math topics. Also, professor Trefor Brazett's channel was also really helpful in terms of Linear Algebra.
#
# For statistics and concept videos on Machine Learning, I don't think there is a better channel than Josh Stammer's StatQuest. I find his videos super educational filled with some silly entertainment in perfect combination. For general code-along tutorials, check out FreeCodeCamp and Corey Schafer's channels. You won't be disappointed.
#
# When it comes it miscellaneous topics and tutorials, blogs are of great help. In this area, Towards Data Science really stands out and this is also where I post the majority of my posts.

# %% [markdown]
# ### 5. Khan Academy

# %% [markdown]
# Math and Statistics are a huge part of Data Science. If you are a complete beginner or switching careers from non-technical field to Data Science, you can get a pretty solid foundational knowledge in math and statistics on Khan Academy.
#
# I love the satisfaction of solving a practice problem right after you watch an indescribably good video by Sal Khan on some hard topic on calculus. Even though some of his videos are old, his delivery is unparalleled to any other similar sources on the Internet.

# %% [markdown]
# ### Small Roadmap Connecting the Above Resources

# %% [markdown]
# Finally, time to put the above sources in order.
#
# If you are absolute beginner, you should start by learning Python. You can either learn the fundamentals for free on YouTube or make a commitment by taking the Data Science career track on DataCamp or Programming For Data Science with Python Nanodegree on Udacity. If you take either one of the last two choices, you can continue to learn data science in a proper order that you won't find yourself lacking the necessary background information in the middle.

# %% [markdown]
# Subscribing to DataCamp or Udacity also ensures that you gain necessary data analysis skills apart from Python. Especially, pay good attention to data visualization, which is an art form on its own, because how you convey your findings from the sea of data speaks a lot about how good a data scientist you are.

# %% [markdown]
# At the same time, learn the fundamentals of data engineering. Mainly, SQL is highly sought-after skill by the majority of companies and it is a must tool to work with massive datasets. You can also enroll in DataCamp's Data Engineering career track which teaches all about SQL. Moreover, you will need to gain familiarity with data design principles about how data storage systems work and learn the core concepts such as data lakes, data warehouses and [object storage](https://lakefs.io/object-storage/).

# %% [markdown]
# At the same time, you need to be learning about statistics. No matter what people say, statistics is a large part of both data science and machine learning starting from beautiful data visualizations to state-of-the-art ML models. At this point, you can start taking statistics courses from Coursera or go through the Statistics playlist by Khan Academy. YouTube videos by Josh Starmer on statistics are also Internet gems.

# %% [markdown]
# Finally, right around the time you feel going for Machine Learning, start learning math. I made a huge mistake of learning Linear Algebra and Calculus way before I got to machine learning. As a result, by the time I finished acquiring data analysis skills and start learning ML algorithms, I already forgot about math due to lack of practice.

# %% [markdown]
# Don't forget to apply your skills to real-world projects throughout your learning journey. Otherwise, you may get a false sense of growth by taking and finishing more and more courses without acquiring much practical experience. And BTW, writing data science blogs like these immensely helps your understanding of hard topics😉.
