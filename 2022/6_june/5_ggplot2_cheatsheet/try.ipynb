# %% [markdown]
# ## Setup

# %%
install.packages("ggplot2")
# Out:
# Warning message:
# "package 'ggplot2' is in use and will not be installed"

# %%
library("tidyverse")

# %%
library("dplyr")

# %%
library("ggplot2")

# %%
diamonds = read_csv("data/diamonds.csv")

head(diamonds)
# Out:
# Rows: 10000 Columns: 10
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (3): cut, color, clarity
# dbl (7): carat, depth, table, price, x, y, z
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   carat cut     color clarity depth table price x    y    z
# 1 1.20  Premium H     SI2     62.3  59     5846 6.82 6.75 4.23
# 2 0.41  Ideal   E     VVS1    61.9  55     1367 4.78 4.79 2.96
# 3 0.35  Ideal   E     VS2     62.0  55      767 4.52 4.54 2.81
# 4 0.61  Premium D     VS2     62.3  55     2251 5.47 5.42 3.39
# 5 0.37  Ideal   E     VS2     61.9  53      811 4.62 4.65 2.87
# 6 1.03  Premium D     VVS2    60.1  58    11335 6.55 6.60 3.95

# %% [markdown]
# ### Basics

# %%
ggplot(diamonds, aes(x=price, y=carat, color="red", size=x)) + geom_point()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=price)) + geom_histogram(binwidth)
# Out:
# plot without title

# %%
ggplot(diamonds, aes(cut, price)) + geom_violin()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(cut, color)) + geom_count()
# Out:
# plot without title

# %%
f <- ggplot(mpg, aes(class, hwy))
f
# Out:
# plot without title
