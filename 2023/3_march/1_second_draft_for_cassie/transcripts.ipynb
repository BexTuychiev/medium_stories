# %% [markdown]
# ### Instructions

# %% [markdown]
# #### Video 1

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("LdN5IF2goGo")

# %% [markdown]
# #### Video 2

# %%
YouTubeVideo("j8VjRnaHRBM")

# %% [markdown]
# # Transcript of MFML 005
# ![image.png](attachment:1277b6b6-af4a-4c55-91d7-1cf59585e51e.png)
#
# What’s inside that black box? Surprise, it’s full of math!

# %% [markdown]
# ![image.png](attachment:f112d691-90a2-4e2e-be27-6b909bd28a98.png)
#
# And on our menu today, we are going to meet the flavor, rather than the equations, of a whole bunch of algorithms. But here’s how we’re going to do it: right now, I’m going to introduce you to this one, and my goal is to set your thinking about these algorithms. What are the important ideas here? And then, later, when 90% of you have fled and gone home or went to play outside, uh, at the very end of the course, after we’ve covered the end-to-end applied machine learning stuff, we’re going to look at all of those.

# %% [markdown]
# So let’s dive in.
#
# ![image.png](attachment:e0d4e2a4-588e-4943-b4c7-70438e28fd4b.png)
#
# Regression was first used in 1805 by Legendre, who doesn’t have a nice painting of him on Wikipedia, so I picked the one for the second person to use it in 1807, Gauss. That’s more than 200 years ago. This has been around for a really long time, and it’s still a really popular standard approach to machine learning today. So let’s have a look.

# %% [markdown]
# # Transcript of MFML 006
# ![image.png](attachment:9811fd64-df93-4197-9e48-0a12f4d4267e.png)
#
# For our example, we will be making smoothies. Every smoothie will have one cup of plain yogurt, one secret ingredient, and a bunch of random food dye, so that you cannot tell what is in there. I blend it up, I serve it to you, and your goal now is to shout at me what are the calories in this smoothie. Go!
#
# ![image.png](attachment:45b6f827-cdf3-4662-950d-fffe27c090a7.png)

# %% [markdown]
# What do I hear? 100, 100, going once, going twice, 300, 500. I’m doing a little test here, seeing who’s got the strongest aptitude in the audience for machine learning. Because the machine learning attitude is not the attitude of perfectionism: think carefully and get the answer right on the first go, and don’t even try it unless it’s going to be perfect. No, the attitude is go for it, see what happens, get it wrong, because you’re going to have to do it over and over again. You’re going to fail, fall down, over and over again, pick yourself up, try again, and eventually, you will get it right. That’s the attitude of machine learning. Try again until it finally works. You have to try something to know what to do next, and if you’re too afraid to start, you tend not to do well in applied machine learning. So, for those of you who are brave enough to just go for it, even though you didn’t know the right answer, that’s what will get me to move to the next slide and give you more information. We’ll be able to iterate towards the correct solution together. Okay, so you’ve unlocked the next slide. It turns out this was the secret ingredient: 58 grams of sardines with 265 calories.
#
# ![image.png](attachment:a6c6dff0-cd1a-4a97-bcf4-54144b4a30f3.png)

# %% [markdown]
# I see you don’t want to drink it. Fine, I’ll make you a different one.
#
# ![image.png](attachment:2ac26f66-f224-4c74-8eb6-7504ccd78f53.png)
#
# Guess the calories: 80, 400, or 180? All right, I’m hearing some more responses and rumblings now. Let me tell you what was in here: 50 grams of not-delicious waffles that I’ve shown you in the picture.
#
# ![image.png](attachment:096943c3-b149-4942-a315-3b685727ef60.png)
#
# No, the raw stuff, waffle mix. This is actually an homage to a standard hazing experience that happens on the fifth floor of the Google office here in New York. Most new Googlers (myself included) have done this: you walk up and you see this delicious smoothie, and you try it, and it is not a smoothie. So, standard newbie hazing experience here. Okay, so you don’t want to drink this one. Fine, I’ll make you a third one,
#
# ![image.png](attachment:a31c6464-a3f7-4d7d-926e-79bd58e20dca.png)
#
# but before I make you guess, I’m going to give you a little more information.

# %% [markdown]
# This is the 16th smoothie that I’ve made, and here are the 15 previous calorie amounts.
#
# ![image.png](attachment:4c19c755-84e1-4ca1-9953-b90b8b39ff4f.png)
#
# Your first reaction to this should be not trying to read it, but instead stamping your foot and saying, ‘I’m a human, I don’t calculate things. Pffft. That’s what machines are for.’ Indeed. Good. The machine will help us out and summarize them. We find out that the average is 237, and the middle value is 240. Have a guess now as to the calories of this one. I’m hearing 238 or 240.
#
# ![image.png](attachment:519aee6f-a23a-4902-b2ab-74296cb04785.png)

# %% [markdown]
# Notice how your range has narrowed a lot as I give you more information. That will be key to our discussion. Okay, I’ll go for 237.
#
# ![image.png](attachment:ec8cd979-6747-4cda-b8c2-6da36133e72e.png)
#
# Ah, it turns out to be 88 grams of quiche lorraine, clocking in at a whopping 445 calories and proving to us that any liquid diet is beatable. So, how did we do? We had an underestimate of 208 calories with that strategy. Can we do better?
#
# ![image.png](attachment:2879f6c6-1f75-4e8d-b674-c6ef2df70e48.png)
#
# Maybe it would help to have the weight of the secret ingredient. So, what we’ll do as analysts is make a little plot and have the weight from 0 to 200 grams on the x-axis, and calories from 0 to 500 on the y-axis.
#
# ![image.png](attachment:88421fc7-b540-47d7-9e03-a571ca89e057.png)
#
# As we look at this, we ask ourselves, is there anything going on, or is weight completely useless here? What do you say, completely useless or something to it? And since there’s something to it, maybe we’ll go ahead and try it out. Shall we? Regression is about putting lines through stuff, so why don’t we put a line through it?
#
# ![image.png](attachment:4f20f27f-07f5-4eea-a4ac-a7a7a1f36006.png)
#
# You like that line? Good line? We missed. Where should we put this line, by the way? For those who forgot how lines work, here’s a handy cheat sheet: the recipe for the model is simply intercept plus slope times the weight. So, we’ll have two numbers here in red that we have to find or determine where the line goes, and then we pop the weight in there and read the calories off of it. So that’s what we’re dealing with — straightforward stuff.
#
# So, you don’t like my line? Okay, fair enough. How about that one? You don’t like that one? This one? It’s a tough crowd. That one? No, this one? You look offended. Why do you look offended by this?
#
# ![image.png](attachment:b469c3a0-7459-4b75-9963-e8ca175f6876.png)
#
# Because let me remind you of something real quick: this right here is your previous model, and now you’re offended, but before you were very happy to just guess 237 every time. 237 and 0 times the weight means I ignore the weight and say 237 every time, and you were so fine to use it. Check your future engineering privilege.

# %% [markdown]
# What is feature engineering? That’s when we create inputs that we might use to learn from, stuff that might inform our solution. And when we have a feature that we might use, suddenly we can do better. So that’s kind of going to be the point here as we get information that’s going to be relevant to solving this thing.
#
# ![image.png](attachment:f146839c-6d62-43aa-8747-a897ce54b84f.png)
#
# We expect to do better, and very it’s going to be up to us to think about what information might be worth putting into the system in the first place. Okay, so let’s do better. If we can do better, we’re going to find a line that’s as close to the points as possible, because you seemed offended when I wasn’t doing that. Fine. So, we better define a notion of an error. What’s an error?
#
# ![image.png](attachment:d7bdf4fa-a0fc-41e7-9049-a74fd7da716b.png)
#
# Just the point minus the line, the truth minus what we were saying we should predict. And because we all have type A personalities here, we hate errors, so we are going to minimize a function of these errors that is going to be the score for how this thing performs. And a good score is to have fewer errors. We will use the root mean squared error (RMSE) here, and this thing is very creatively named. It’s actually the recipe for calculating it backwards: get the error, square the error, take the mean or average, and take the square root of that. RMSE, or root mean squared error, or you could just think of the RMSE as the calories we’re off by on average.
#
# ![image.png](attachment:8fa250f4-9c92-4932-9a02-026556821fc3.png)
#
# Not technically correct, but good enough for government work. We’re off by about 85 calories on average, and that’ll do. That fine for a morning, so now we’re off by 85 and we want to be off by fewer. So let’s see if we can just jiggle those two parameters there in the recipe to make things better.
#
# What do you want to do? Maybe you want to increase the slope a bit. Okay, that’s getting better. Good. How about we increase the slope a little more? Not so much better. Maybe now we want to move the intercept down, so let’s do that. And what we could do is we could continue tinkering with these two numbers with slow, boring tinkering, or we could get on with it. So, what are our options?
#
# ![image.png](attachment:5e3faf69-03ae-4ac9-b4b2-89c086276296.png)
#
# Just play by hand with those two numbers, which is what we were doing, or we could use calculus, but who even does calculus anymore, so old school, or we could just use an optimization algorithm to get us the answer immediately. So, what does an optimization algorithm do? It says, for this setting you are trying, what’s your goal? You are trying to get this function right here to be as low as possible. Let me figure out for you what settings on those two parameters that I’m allowed to play with give me the best possible performance here, and then it outputs you that answer. And that’s going to be in the heart of every machine learning algorithm. So, we’re going to need to know what the scoring is, what the goal is, and then it’s going to figure out where to set the uh, free parameters in the recipe based on that. Okay, great. And we have come a long way. I’m impressed with this. Nice. Uh, let’s look at quiche lorraine, though. It’s taunting us. We did not predict quiche lorraine well. Can we do better?
