# %% [markdown]
# # 5 Long Overdue Computer Memory Concepts to Learn as an ML Engineer
# ![Ariel view of a giant circuit board built like a metropolitan city.png](attachment:c28582b4-56f4-4a03-827c-3c7916b14eab.png)

# %% [markdown]
# ### Introduction

# %% [markdown]
# - Ever wonder what happens when you fire up jupyter and load a dataset in Pandas. Well, million of operations.
# - But perhaps, the most common operation is the copying of data from your SSD (HDD if you are archaic) to your RAM.
#
# - That's why there is some time before you see the jupyter interace, it takes time for copying to take place
# - SSD stores permanently store data in the form of massive 3D arrays composed of trillion of more memory cells
# - DRAM stores

# %% [markdown]
# ### Conclusion
