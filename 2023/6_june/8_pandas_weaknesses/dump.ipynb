# %% [markdown]
# # 10 Weaknesses the Author of Pandas Admits About His Own Library
# ## and the modern day alternatives that can overcome them
# ![bexgboost_A_glowing_ethereal_light_radiating_from_the_end_of_a__455d0a58-39cc-45f9-992a-f2a24b3f24dd.png](attachment:b57acc54-8720-4d87-942b-f158c2655691.png)

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### The alternatives

# %% [markdown]
# ### Conclusion
