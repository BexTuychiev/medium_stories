# %% [markdown]
# # 5 Steps to Share Any Machine Learning Model in a Docker Container
# ## Docker for the modern machine learning engineer
# ![bexgboost_A_colossal_submarine_its_hull_resembling_a_whale_with_69a4facc-55bf-4ecf-acae-b2f2992a83fd.png](attachment:00badee2-4a78-46fb-b88f-4300f6b41355.png)

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Step 0: Prepare the model and save it

# %% [markdown]
# ### Step 1: List the dependencies

# %% [markdown]
# ### Step 2: Write a Dockerfile

# %% [markdown]
# ### Step 3: Build the image

# %% [markdown]
# ### Step 4: Test the container

# %% [markdown]
# ### Step 5: Share the container

# %% [markdown]
# ### Conclusion
