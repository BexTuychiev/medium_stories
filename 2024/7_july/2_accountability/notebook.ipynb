# %% [markdown]
# # $40 Accountability System That Cured My Procrastination For Good
# ## You won't ever put off a task again

# %% [markdown]
# ## How I put together the system

# %% [markdown]
# To everyone's eyes, I was doing well. I was in college but had no debt. I was working "hard" to cover my tuition and cost of living in a capital city. My career was off to a good start: I was gaining serious attention as a data science writer on Medium.
#
# But behind it all was mountainous guilt and shame because I was actually wasting the prime of my life. Even people closest to me didn't know that I was spending only a few hours a day doing working on my future.
#
# If you know what you are doing, a few hours a day is all it takes to earn $1000+ a month on the Internet. And where I live (Uzbekistan), $1000 is enough for a single guy to live a comfortable, almost rich life.
#
# With the rest of my time, I was sleeping 8-10 hours a day, binge-watching entire Netflix and Disney+ for weeks on end, playing video games until my eyes hurt, occasionally studying what I absolutely had to for college (turns out, it isn't much).
#
# The combination of early and easy financial prosperity and the fact that a college degree doesn't amount to much in my field of work turned me into a log floating through life.
#
# When I turned 21, I realized that the root of all my problems was procrastination. It wasn't laziness or being untalented. It was a case of procrastination caused by a lack of life problems (the possibility of not making rent, fear of being expelled from college and so on) that force others to act and not self-sabotage themselves.
#
# Too many "I still have time"s or "I will start from Monday"s had passed. I had enough. So, I set on a journey of self-improvement. I took courses, read self-help articles and books, tried many productivity hacks but they were only effective until the novelty wore off (usually in about a week).
#
# They didn't work because the underlying issue was still not addressed - I could continue drifting through life, live comfortably and survive. I didn't have the pressure.
#
# Everything changed when I, through blind luck, put together a system of tools that could hold me accountable to virtually any task I wanted to do. This system now charges real money if I fail to complete a goal for the day.
#
# I found that a serious pocket damage was an excellent motivator to get out of the couch and get stuff done.
#
# Now, let me share with you that system.

# %% [markdown]
# ## 1. Beeminder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Price: $8/month

# %% [markdown]
# - The first part of the system was discovering Beeminder - a habit tracker that stings, or in other words, charges your credit card when you _derail_ from your daily commitment.
# - The pledge (amount of money to charge) for each goal tracked with Beeminder starts with $5. Every derailment increases your pledge until you reach a pledge cap. The cap must be any amount of money you wouldn't feel comfortable losing for skipping a daily habit.
# - The best part of all this is that any change to a Beeminder habit has a 7-day lag period before taking effect. So, if you realize you are derailing for the day, you won't be able to stop it by making the habit easier, lowering the pledge amount or deleting the habit itself.
# - Of course, the question is "How does Beeminder know you completed your habit for the day?". This is where Beeminder integrations come in:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Beeminder can connect to APIs (underlying mechanisms) of popular productivity, health, work-related apps to automatically figure out whether you are lying or not.
# - Want to force yourself to go swimming for a certain number of laps each day?
# - Create a Beeminder habit that connects to your Strava or fitbit account
# - Want to code for three hours each day without fail? Link Beeminder to WakaTime, which measures the time you spend in a code editor
# - Want to decrease the time you spend doom-scrolling?
# - Hook up to time trackers such as RescueTime or toggltrack. They will rat you out to Beeminder if you spend too much time on Reddit.
# - Beeminder was awesome and it worked really well for about a month.
# - But I, a master procrastinator, found ways to cheat it.
# - For example, for my biking goal, I could add a manual activity to my Strava so that Beeminder thought I rode for 10km for the day.
# - Or for my writing goal, I could copy-paste a 50-word paragraph multiple times until the total count reached the word limit.
# - I realized that any Beeminder integration had some sort of a loophole I could take advantage whenever I want.
# - Expect for one: Boss as a Service.

# %% [markdown]
# ## 2. Boss as a Service

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Price: $25/month

# %% [markdown]
# Boss as a Service (BaaS) does exactly what it says in the name: gives you an actual human boss for $25 a month.
#
# In the morning, you text your boss telling what you wish to accomplish for the day. The boss checks in with you at the end of the day to see visual proofs of the tasks you completed. It can be a short video of you standing in the gym stating the date and hour of the day or a screenshot of an email you sent to your client after you completed an assignment. If there is an unfinished task, they follow up with you (pretty insistently) until it is resolved.
#
# BaaS on its own wouldn't help me much because this boss couldn't fire me or yell at me for not finishing an article. They must have realized this loophole in their service because BaaS also integrates with Beeminder.
#
# Now imagine the possibilities - with BaaS and Beeminder combined, you could
# - Be part of the "5AM Club"
# - Take cold showers
# - Finally start that side business
# - Journal every day
#
# or force yourself to do any unpleasant but necessary task you have been putting off all your life. All you have to do is figure out how to convert your goal or dream to a daily habit, add it to Beeminder and share the habit link with your boss at BaaS. Then, you send proofs of completion to your boss and they inform Beeminder on your behalf.
#
# To make absolutely sure you don't cheat, ask your boss to turn on "No excuses mode" from both ends (BaaS and Beeminder). Unless you communicate a viable reason beforehand, your boss will derail you without mercy. With an actual human in the loop, the level of strictness you can impose on yourself is infinitely flexible.

# %% [markdown]
# ## 3. FocusMe and iPhone Screen Time

# %% [markdown]
# Price: $8/month

# %% [markdown]
# We live in a time where so many different things battle for our attention. So, it is easy to get sucked into one of them with or without real money stakes. For this reason, I've made FocusMe and iPhone's screen time statistics part of my accountability system.
#
# Together, they tell my boss how much time I spend on unwanted things like gaming or social media. I have "Do-less" Beeminder habits that charge me money if I exceed my daily limit.
#
# I've chosen FocusMe because it is the most unbreakable distractions blocker on the Internet (I can vouch for it as a programmer). It has a "Forced" mode that makes it impossible to disable or break when you block a certain website or an application until a timer runs out. It also collects infallible and uneditable screen time statistics:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# FocusMe is available on macOS, Windows and Android, so I use Screen Time to track my iPhone usage.
#
# The loophole in this process is that if I share my screen time at 9pm in the evening and spend the rest of the day gaming, my boss wouldn't know. So, I share both today's and yesterday's statistics to eliminate any chance of cheating.

# %% [markdown]
# ## How to Fit Any Habit Into the System

# %% [markdown]
# Getting started with three new tools can be overwhelming, so let me share you a step-by-step plan to fit anything you want to do into the system.
#
# __1. Sign up for plans in all three platforms__
#
# After you sign up for BaaS, your assigned boss will reach out within 24 hours. In the meantime, you can start setting up Beeminder. The moment you create an account there, Beeminder presents you with a 7-day timer to create your first habit. If you don't, you will lose $5. Then, you can buy a license for FocusMe and create plans for how you spend your time. Even if you didn't use Beeminder or BaaS, FocusMe is a must in this distraction-ridden world.
#
# __2. Make your goal quantifiable__
#
# Beeminder can only help you if what you want to do is measurable in terms of:
# - How many times it is done
# - Time spent doing
# - Distance covered
#
# In the paid plans, you can create "Do less" goals for things you want to quit. That's why my Beeminder subscription costs $8. If you have got nothing to quit (doubt it), the free plan is enough.
#
# __3. Share habit link with your boss__
#
# Each Beeminder habit has a URL that points to its dashboard:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# You must share that URL with your boss so that they can add data points to it using the BaaS integration. You can read this guide for more information on setup.
#
# __4. Turn on "No excuses mode" in Beeminder__
#
# Whenever you derail from your daily commitment, Beeminder sends you an email asking whether you have a viable excuse for failing before charging you. As per their policy, they can cancel the charge if you say (or lie) you have a valid reason. That's why you must turn on the following option at the end of each habit settings:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can also tell your boss not to accept any excuses from you when you fail your tasks. After we agreed with my boss on this, my success rate increased much more because I was always looking for something to blame if I came up short at the end of the day.

# %% [markdown]
# ## Conclusion
